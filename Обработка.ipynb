# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('chinese_cars_final.csv')
data
# Out:
#                                     Название  Марка  \
# 0         Chery Tiggo 7 Pro Max I Рестайлинг  Chery
# 1                  Haval Jolion I Рестайлинг  Haval
# 2                                Haval H9 II  Haval
# 3                            Chery Tiggo 9 I  Chery
# 4                                   Haval H3  Haval
# ...                                      ...    ...
# 3010  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
# 3011                              Geely Icon  Geely
# 3012                              Geely Icon  Geely
# 3013                         Geely Atlas Pro  Geely
# 3014  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
#
#                                 Модель Пробег, км Мощность двигателя, л  \
# 0         Tiggo 7 Pro Max I Рестайлинг      Новый                   1.6
# 1                  Jolion I Рестайлинг      Новый                   1.5
# 2                                H9 II      Новый                   2.4
# 3                            Tiggo 9 I      Новый                   2.0
# 4                                   H3     12 000                   1.5
# ...                                ...        ...                   ...
# 3010  Monjaro (Xingyue L) I Рестайлинг         10                   2.0
# 3011                              Icon          1                   1.5
# 3012                              Icon         10                   1.5
# 3013                         Atlas Pro     58 000                   1.5
# 3014  Monjaro (Xingyue L) I Рестайлинг         10                   2.0
#
#      Мощность двигателя, л.с  Год выпуска Цена от, руб   Цена до, руб  \
# 0                        150         2025   2 149 000   Not available
# 1                        150         2025   1 820 000   Not available
# 2                        184         2024   3 454 000   Not available
# 3                        249         2024   3 535 000   Not available
# 4                        177         2024    2 320 000      2 320 000
# ...                      ...          ...          ...            ...
# 3010                     238         2025    3 830 000      3 830 000
# 3011                     181         2024    2 699 999      2 699 999
# 3012                     181         2024    2 699 999      2 699 999
# 3013                     177         2022    2 100 000      2 100 000
# 3014                     238         2025    3 750 000      3 750 000
#
#       Цвет кузова Коробка передач    Привод Тип топлива Город продажи
# 0      Active AWD           робот    полный      Бензин      Балашиха
# 1           Elite           робот    полный      Бензин         Химки
# 2           Elite         автомат    полный      Дизель        Москва
# 3           Ultra         автомат    полный      Бензин        Москва
# 4           серый           робот    полный      Бензин        Москва
# ...           ...             ...       ...         ...           ...
# 3010  серебристый         автомат    полный      Бензин        Москва
# 3011      голубой           робот  передний      Бензин        Москва
# 3012        серый           робот  передний      Бензин        Москва
# 3013        синий           робот    полный      Бензин      Одинцово
# 3014      зелёный         автомат    полный      Бензин        Москва
#
# [3015 rows x 14 columns]

# %% [markdown]
# # Предобработка

# %%
data.dtypes
# Out:
# Название                   object
# Марка                      object
# Модель                     object
# Пробег, км                 object
# Мощность двигателя, л      object
# Мощность двигателя, л.с    object
# Год выпуска                 int64
# Цена от, руб               object
# Цена до, руб               object
# Цвет кузова                object
# Коробка передач            object
# Привод                     object
# Тип топлива                object
# Город продажи              object
# dtype: object

# %%
data.rename(columns={'Пробег, км' : 'Пробег', 
                     'Мощность двигателя, л': 'Мощность_1', 
                     'Мощность двигателя, л.с': 'Мощность_2',
                     'Цена от, руб': 'Цена', 
                     'Цвет кузова': 'Цвет',
                     'Коробка передач': 'Коробка_передач',
                     'Тип топлива': 'Тип_топлива',
                     'Город продажи': 'Город'}, inplace=True)

# %%
for col in data.columns:
    print(f'Название колонки {col}')
    print(data[col].value_counts())
    print('----------------------------------------')
    print()
# Out:
# Название колонки Название
# Название
# Chery Tiggo 7 Pro Max I Рестайлинг        326
# Geely Monjaro (Xingyue L) I Рестайлинг    292
# Chery Tiggo 4 I Рестайлинг 2              158
# Chery Tiggo 9 I                           154
# Geely Atlas Pro                           112
#                                          ...
# Haval H8                                    1
# Chery Tiggo 5 I Рестайлинг                  1
# Chery Tiggo 8 Plus I                        1
# Chery M11 (A3)                              1
# Geely GS I                                  1
# Name: count, Length: 82, dtype: int64
# ----------------------------------------
#
# Название колонки Марка
# Марка
# Chery    1232
# Geely    1106
# Haval     675
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Модель
# Модель
# Tiggo 7 Pro Max I Рестайлинг        326
# Monjaro (Xingyue L) I Рестайлинг    292
# Tiggo 4 I Рестайлинг 2              158
# Tiggo 9 I                           154
# Atlas Pro                           112
#                                    ...
# H8                                    1
# Tiggo 5 I Рестайлинг                  1
# Tiggo 8 Plus I                        1
# M11 (A3)                              1
# GS I                                  1
# Name: count, Length: 82, dtype: int64
# ----------------------------------------
#
# Название колонки Пробег
# Пробег
# Новый     1312
# 10         206
# 1          127
# 5 000       88
# 5           84
#           ...
# 3 072        1
# 37 471       1
# 63 976       1
# 75 000       1
# 19 003       1
# Name: count, Length: 363, dtype: int64
# ----------------------------------------
#
# Название колонки Мощность_1
# Мощность_1
# 1.5    1413
# 2.0    1108
# 1.6     448
# 2.4      28
# 1.8      10
# 1.3       4
# 1.9       2
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Мощность_2
# Мощность_2
# 150    582
# 147    373
# 238    367
# 192    190
# 143    172
# 249    149
# 113    139
# 181    136
# 177    134
# 190    115
# 197    103
# 174     90
# 200     87
# 186     59
# 152     55
# 122     43
# 109     36
# 218     29
# 172     29
# 139     27
# 184     25
# 235     25
# 149      9
# 245      8
# 156      5
# 83       4
# 163      3
# 126      3
# 132      2
# 129      2
# 136      2
# 106      2
# 169      2
# 88       1
# 117      1
# 98       1
# 94       1
# 133      1
# 119      1
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Год выпуска
# Год выпуска
# 2024    1380
# 2025     709
# 2023     334
# 2022     260
# 2021     128
# 2020     101
# 2019      39
# 2011      31
# 2018       9
# 2014       5
# 2009       3
# 2017       3
# 2007       3
# 2015       2
# 2012       2
# 2013       2
# 2010       1
# 2008       1
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Цена
# Цена
# Not available    398
# 2 699 999        133
# 1 550 000         61
# 3 830 000         59
# 1 386 000         58
#                 ...
# 4 950 000          1
# 2 414 190          1
# 4 057 000          1
# 1 992 000          1
# 3 333 000          1
# Name: count, Length: 582, dtype: int64
# ----------------------------------------
#
# Название колонки Цена до, руб
# Цена до, руб
# Not available    1555
# 2 699 999         133
# 1 550 000          61
# 3 830 000          59
# 2 245 000          58
#                  ...
# 1 207 000           1
# 2 299 000           1
# 1 048 000           1
# 996 000             1
# 2 150 000           1
# Name: count, Length: 231, dtype: int64
# ----------------------------------------
#
# Название колонки Цвет
# Цвет
# серый                   380
# белый                   336
# чёрный                  330
# серебристый             221
# Ultra                   180
# зелёный                 150
# Active                  139
# Prime                   135
# синий                   123
# Tech Plus               114
# Premium                  91
# Prime AWD                88
# Action                   88
# Elite                    82
# жёлтый                   65
# Tech+                    56
# Ultra AWD                49
# Flagship                 47
# голубой                  38
# Active AWD               32
# Elite FWD                24
# Comfort                  24
# красный                  22
# фиолетовый               22
# Ultimate                 21
# Luxury                   17
# Family                   16
# Flagship Sport           16
# Dreamline                15
# Dreamline 4WD            14
# Dreamline FWD            13
# Ultimate 4WD             12
# Exclusive                12
# Ultra Black              12
# пурпурный                 7
# Style                     6
# коричневый                5
# Flagship (2023)           3
# оранжевый                 1
# X Premium                 1
# Standard                  1
# Luxury (2023)             1
# X Elite                   1
# Prestige                  1
# золотистый                1
# Flagship (Xingyue L)      1
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Коробка_передач
# Коробка_передач
# робот       1850
# автомат      815
# механика     195
# вариатор     153
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Привод
# Привод
# передний    1616
# полный      1397
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Тип_топлива
# Тип_топлива
# Бензин    2934
# Дизель      53
# Гибрид      26
# Name: count, dtype: int64
# ----------------------------------------
#
# Название колонки Город
# Город
# Москва                                    1707
# Балашиха                                   593
# Тула (170 км от Москвы)                    145
# Тимохово                                    63
# Северо-Западный административный округ      59
# Химки                                       52
# Вербилки                                    31
# Калуга (160 км от Москвы)                   28
# Исаково                                     28
# Одинцово                                    27
# Рязань (180 км от Москвы)                   26
# Королёв                                     25
# Обнинск                                     24
# Ржавки                                      23
# Московский                                  21
# Владимир (170 км от Москвы)                 20
# Мытищи                                      18
# Тверь (160 км от Москвы)                    18
# Подольск                                    15
# Ногинск                                     11
# Красногорск                                 10
# Люберцы                                      7
# Котельники                                   7
# Коломна (100 км от Москвы)                   5
# Краснознаменск                               4
# Пушкино                                      3
# Истра                                        3
# Электросталь                                 3
# Щёлково                                      2
# Серпухов                                     2
# Видное                                       2
# Путилково                                    2
# Лобня                                        2
# Егорьевск                                    2
# Солнечногорск                                1
# Протвино (100 км от Москвы)                  1
# Раменское                                    1
# Звенигород                                   1
# Старая Купавна                               1
# Архангельское                                1
# Лыткарино                                    1
# Павловский Посад                             1
# Суздальский район (180 км от Москвы)         1
# Сергиев Посад                                1
# Шестово                                      1
# Волоколамск (100 км от Москвы)               1
# Братеево                                     1
# Электроугли                                  1
# Орехово-Зуево                                1
# Сухарево                                     1
# Можайск (100 км от Москвы)                   1
# Коммунарка                                   1
# Тёплый Стан                                  1
# Шатура (120 км от Москвы)                    1
# Асерхово (160 км от Москвы)                  1
# Дмитров                                      1
# Раздоры                                      1
# Лосино-Петровский                            1
# Реутов                                       1
# Name: count, dtype: int64
# ----------------------------------------

# %%
# Убираем строки, где мощность принимает странное значение
data = data[~data['Мощность_1'].str.contains('218')]

# %%
# Убираем лишние символы
#data['Mощность_2'] = data['Мощность_2'].replace('160 кВт', '160')

# %%
# Убираеи записи, по которым не знаем цену
data = data[data['Цена'] != 'Not available']

# %%
# В колонку Цвета попала комплектация, убираем странные записи и оставляем только цвета
real_colors = [
    'серый', 'белый', 'чёрный', 'серебристый', 'зелёный', 'синий', 
    'жёлтый', 'голубой', 'фиолетовый', 'красный', 'пурпурный', 
    'коричневый', 'оранжевый', 'золотистый', 'Ultra Black'
]

data = data[data['Цвет'].isin(real_colors)]

# %%
# Создаем новый признак с группами по цвету

color_groups = {
    'Нейтральные': ['серый', 'белый', 'чёрный', 'серебристый', 'Ultra Black'],  
    'Холодные': ['синий', 'голубой', 'зелёный'],  
    'Тёплые': ['красный', 'жёлтый', 'оранжевый', 'золотистый'],  
    'Экзотические': ['фиолетовый', 'пурпурный', 'коричневый']  
}
def map_color_to_group(color):
    for group, colors in color_groups.items():
        if color in colors:
            return group
    return 'Другие'

data['Цвет_группа'] = data['Цвет'].apply(map_color_to_group)

# %%
data['Цвет_группа'].value_counts()
# Out:
# Цвет_группа
# Нейтральные     987
# Холодные        226
# Тёплые           73
# Экзотические     29
# Name: count, dtype: int64

# %%
# создаем признак is_new
data['is_new'] = data['Пробег'] == 'Новый'

# Заменяем "новый" в колонке пробег на 0
data['Пробег'] = data['Пробег'].replace('Новый', '0')

# %%
# Определяем группы городов
city_groups = {
    'Москва': [
        'Москва',
        'Северо-Западный административный округ',
        'Братеево',
        'Тёплый Стан',
        'Коммунарка'
    ],
    'Московская область': [
        'Балашиха', 'Химки', 'Королёв', 'Мытищи', 'Подольск', 
        'Люберцы', 'Красногорск', 'Одинцово', 'Видное', 'Лобня',
        'Котельники', 'Дмитров', 'Реутов', 'Щёлково', 'Серпухов',
        'Электросталь', 'Ногинск', 'Раменское', 'Звенигород',
        'Павловский Посад', 'Орехово-Зуево', 'Можайск (100 км от Москвы)'
    ],
    'Ближние регионы (до 200 км)': [
        'Тула (170 км от Москвы)', 'Калуга (160 км от Москвы)',
        'Рязань (180 км от Москвы)', 'Владимир (170 км от Москвы)',
        'Тверь (160 км от Москвы)', 'Коломна (100 км от Москвы)',
        'Волоколамск (100 км от Москвы)', 'Суздальский район (180 км от Москвы)',
        'Асерхово (160 км от Москвы)', 'Протвино (100 км от Москвы)'
    ],
    'Города-спутники': [
        'Тимохово', 'Ржавки', 'Московский', 'Вербилки',
        'Исаково', 'Обнинск', 'Лосино-Петровский', 'Раздоры'
    ]
}

def map_city_to_group(city):
    normalized_city = city.split(' (')[0].strip()
    
    for group, cities in city_groups.items():
        if any(normalized_city in c for c in cities):
            return group
    return 'Прочие города'

data['Город_группа'] = data['Город'].apply(map_city_to_group)
data
# Out:
#                                     Название  Марка  \
# 4                                   Haval H3  Haval
# 32                       Chery Tiggo 4 Pro I  Chery
# 35                                  Haval H3  Haval
# 57               Geely Okavango I Рестайлинг  Geely
# 60                Chery Tiggo 8 I Рестайлинг  Chery
# ...                                      ...    ...
# 3010  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
# 3011                              Geely Icon  Geely
# 3012                              Geely Icon  Geely
# 3013                         Geely Atlas Pro  Geely
# 3014  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
#
#                                 Модель  Пробег Мощность_1 Мощность_2  \
# 4                                   H3  12 000        1.5        177
# 32                       Tiggo 4 Pro I  52 460        1.5        113
# 35                                  H3   6 308        1.5        177
# 57               Okavango I Рестайлинг  17 169        2.0        200
# 60                Tiggo 8 I Рестайлинг  22 000        1.5        147
# ...                                ...     ...        ...        ...
# 3010  Monjaro (Xingyue L) I Рестайлинг      10        2.0        238
# 3011                              Icon       1        1.5        181
# 3012                              Icon      10        1.5        181
# 3013                         Atlas Pro  58 000        1.5        177
# 3014  Monjaro (Xingyue L) I Рестайлинг      10        2.0        238
#
#       Год выпуска       Цена Цена до, руб         Цвет Коробка_передач  \
# 4            2024  2 320 000    2 320 000        серый           робот
# 32           2024  1 490 000    1 490 000        серый        механика
# 35           2024  2 650 000    2 650 000       чёрный           робот
# 57           2023  2 980 000    2 980 000        синий           робот
# 60           2022  1 500 000    1 500 000        серый           робот
# ...           ...        ...          ...          ...             ...
# 3010         2025  3 830 000    3 830 000  серебристый         автомат
# 3011         2024  2 699 999    2 699 999      голубой           робот
# 3012         2024  2 699 999    2 699 999        серый           робот
# 3013         2022  2 100 000    2 100 000        синий           робот
# 3014         2025  3 750 000    3 750 000      зелёный         автомат
#
#         Привод Тип_топлива     Город  Цвет_группа  is_new        Город_группа
# 4       полный      Бензин    Москва  Нейтральные   False              Москва
# 32    передний      Бензин    Москва  Нейтральные   False              Москва
# 35      полный      Бензин    Москва  Нейтральные   False              Москва
# 57    передний      Бензин  Балашиха     Холодные   False  Московская область
# 60    передний      Бензин    Москва  Нейтральные   False              Москва
# ...        ...         ...       ...          ...     ...                 ...
# 3010    полный      Бензин    Москва  Нейтральные   False              Москва
# 3011  передний      Бензин    Москва     Холодные   False              Москва
# 3012  передний      Бензин    Москва  Нейтральные   False              Москва
# 3013    полный      Бензин  Одинцово     Холодные   False  Московская область
# 3014    полный      Бензин    Москва     Холодные   False              Москва
#
# [1315 rows x 17 columns]

# %%
data['Город_группа'].value_counts()
# Out:
# Город_группа
# Москва                         1044
# Города-спутники                 147
# Московская область               89
# Ближние регионы (до 200 км)      22
# Прочие города                    13
# Name: count, dtype: int64

# %%
data['Модель'].unique()
# Out:
# array(['H3', 'Tiggo 4 Pro I', 'Okavango I Рестайлинг',
#        'Tiggo 8 I Рестайлинг', 'Tiggo 8 Pro Max I', 'Tiggo 7 Pro Max I',
#        'H9 II', 'Atlas II', 'F7x I', 'F7 I Рестайлинг',
#        'Monjaro (Xingyue L) I Рестайлинг', 'Tiggo 7 Pro I',
#        'Tiggo 4 I Рестайлинг', 'Jolion I', 'F7 II', 'Monjaro I',
#        'Tiggo (T11) I', 'Tiggo 8 Plus I', 'Tiggo 7 Pro Max I Рестайлинг',
#        'H6 Coupe I', 'Tiggo 7 Pro Plug-in Hybrid', 'Atlas Pro', 'Atlas I',
#        'Arrizo 8', 'Dargo', 'Preface I (China Market) Рестайлинг',
#        'Cityray', 'H5 II', 'Tiggo 8 Pro e+', 'Tiggo 8 Pro I',
#        'Tugella I Рестайлинг', 'Xingyue I', 'Yuancheng (Farizon) FX',
#        'Tiggo 4 Pro I Рестайлинг', 'QQ6 (S21)', 'Coolray I',
#        'Coolray I Рестайлинг', 'F7 I', 'Preface I', 'Amulet (A15) I',
#        'Preface I (China Market)', 'M11 (A3)', 'H9 I Рестайлинг',
#        'Coolray (Binyue Cool) I Рестайлинг', 'H2',
#        'Monjaro (Xingyue L) Hi-F I', 'Emgrand II', 'F7x I Рестайлинг',
#        'Jolion I Рестайлинг', 'H5 I', 'H8', 'Dargo X', 'M6 II',
#        'Emgrand EC7', 'IndiS (S18D) I', 'MK Cross I', 'Boyue Cool',
#        'H6 Red Label Sport I', 'Bonus 3 (E3/A19)',
#        'Monjaro (Xingyue L) I', 'Tiggo 8 I',
#        'Tiggo 8 Pro Max I Рестайлинг', 'Kimo (A1)',
#        'Vision X3 I Рестайлинг', 'Tiggo 7 II', 'Tiggo 7 I', 'Very (A13)',
#        'Icon', 'Jiaji L I Рестайлинг', 'M6 I Рестайлинг', 'Okavango I'],
#       dtype=object)

# %%
def extract_car_features(df):
    # 1. Базовое название модели
    df['base_model'] = df['Модель'].apply(
        lambda x: re.sub(r'\s(I+|II|III|IV|Рестайлинг|Pro|Max|Plus|Plug-in|Hybrid|China Market|\(.*?\)|\d)', '', x).strip()
    )
    
    # 2. Поколение модели (римские цифры)
    df['generation'] = data['Модель'].str.findall(r'\b(I{1,4}|IV)\b').apply(
        lambda x: x[-1] if len(x) > 0 else 'I').replace({'I':1, 'II':2, 'III':3, 'IV':4})
    
    # 3. Технологические особенности
    df['is_restyling'] = df['Модель'].str.contains('Рестайлинг').astype(int)
    df['is_pro'] = df['Модель'].str.contains('Pro').astype(int)
    df['is_max'] = df['Модель'].str.contains('Max').astype(int)
    
    # 4. Класс автомобиля (на основе экспертных правил)
    def get_car_class(row):
        brand = row['Марка']
        model = row['base_model']
        
        class_rules = {
            'Haval': {
                'H[3-9]': 'SUV',
                'Jolion|Dargo': 'Crossover',
                'F[7-9]': 'Luxury SUV'
            },
            'Chery': {
                'Tiggo [4-8]': 'SUV',
                'Arrizo|Amulet': 'Sedan',
                'QQ': 'City Car'
            },
            'Geely': {
                'Atlas|Xingyue': 'SUV',
                'Coolray|Monjaro': 'Crossover',
                'Emgrand|Preface': 'Sedan'
            }
        }
        
        for pattern, cls in class_rules[brand].items():
            if re.search(pattern, model):
                return cls
        return 'Other'
    
    df['car_class'] = df.apply(get_car_class, axis=1)
    
    
    # 5. Рыночная сегментация
    df['is_premium'] = df['base_model'].str.contains('Max|Pro|Plus|Monjaro|Xingyue').astype(int)
    
    # 6. Популярность модели
    model_popularity = df['base_model'].value_counts().to_dict()
    df['model_popularity'] = df['base_model'].map(model_popularity)
    
    return df

extract_car_features(data)
# Out:
#                                     Название  Марка  \
# 4                                   Haval H3  Haval
# 32                       Chery Tiggo 4 Pro I  Chery
# 35                                  Haval H3  Haval
# 57               Geely Okavango I Рестайлинг  Geely
# 60                Chery Tiggo 8 I Рестайлинг  Chery
# ...                                      ...    ...
# 3010  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
# 3011                              Geely Icon  Geely
# 3012                              Geely Icon  Geely
# 3013                         Geely Atlas Pro  Geely
# 3014  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
#
#                                 Модель  Пробег Мощность_1 Мощность_2  \
# 4                                   H3  12 000        1.5        177
# 32                       Tiggo 4 Pro I  52 460        1.5        113
# 35                                  H3   6 308        1.5        177
# 57               Okavango I Рестайлинг  17 169        2.0        200
# 60                Tiggo 8 I Рестайлинг  22 000        1.5        147
# ...                                ...     ...        ...        ...
# 3010  Monjaro (Xingyue L) I Рестайлинг      10        2.0        238
# 3011                              Icon       1        1.5        181
# 3012                              Icon      10        1.5        181
# 3013                         Atlas Pro  58 000        1.5        177
# 3014  Monjaro (Xingyue L) I Рестайлинг      10        2.0        238
#
#       Год выпуска       Цена Цена до, руб         Цвет  ... is_new  \
# 4            2024  2 320 000    2 320 000        серый  ...  False
# 32           2024  1 490 000    1 490 000        серый  ...  False
# 35           2024  2 650 000    2 650 000       чёрный  ...  False
# 57           2023  2 980 000    2 980 000        синий  ...  False
# 60           2022  1 500 000    1 500 000        серый  ...  False
# ...           ...        ...          ...          ...  ...    ...
# 3010         2025  3 830 000    3 830 000  серебристый  ...  False
# 3011         2024  2 699 999    2 699 999      голубой  ...  False
# 3012         2024  2 699 999    2 699 999        серый  ...  False
# 3013         2022  2 100 000    2 100 000        синий  ...  False
# 3014         2025  3 750 000    3 750 000      зелёный  ...  False
#
#             Город_группа base_model generation is_restyling  is_pro is_max  \
# 4                 Москва         H3          1            0       0      0
# 32                Москва      Tiggo          1            0       1      0
# 35                Москва         H3          1            0       0      0
# 57    Московская область   Okavango          1            1       0      0
# 60                Москва      Tiggo          1            1       0      0
# ...                  ...        ...        ...          ...     ...    ...
# 3010              Москва    Monjaro          1            1       0      0
# 3011              Москва       Icon          1            0       0      0
# 3012              Москва       Icon          1            0       0      0
# 3013  Московская область      Atlas          1            0       1      0
# 3014              Москва    Monjaro          1            1       0      0
#
#       car_class  is_premium  model_popularity
# 4           SUV           0                 4
# 32        Other           0               270
# 35          SUV           0                 4
# 57        Other           0                 7
# 60        Other           0               270
# ...         ...         ...               ...
# 3010  Crossover           1               319
# 3011      Other           0                80
# 3012      Other           0                80
# 3013        SUV           0               132
# 3014  Crossover           1               319
#
# [1315 rows x 25 columns]

# %%
data.rename(columns={'Название': 'name',
                     'Модель': 'model',
                     'Марка': 'brand',
                     'Пробег': 'mileage',
                     'Мощность_1': 'power_1',
                     'Мощность_2': 'power_2',
                     'Год выпуска': 'year',
                     'Привод': 'drive',
                     'Цена': 'price',
                     'Цвет': 'color',
                     'Коробка_передач': 'gearbox',
                     'Тип_топлива': 'fuel_type',
                     'Город': 'city',
                     'Цвет_группа': 'color_group',
                     'Город_группа': 'city_group'}, inplace=True
                     )

# %%
data
# Out:
#                                         name  brand  \
# 4                                   Haval H3  Haval
# 32                       Chery Tiggo 4 Pro I  Chery
# 35                                  Haval H3  Haval
# 57               Geely Okavango I Рестайлинг  Geely
# 60                Chery Tiggo 8 I Рестайлинг  Chery
# ...                                      ...    ...
# 3010  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
# 3011                              Geely Icon  Geely
# 3012                              Geely Icon  Geely
# 3013                         Geely Atlas Pro  Geely
# 3014  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
#
#                                  model mileage power_1 power_2  year  \
# 4                                   H3  12 000     1.5     177  2024
# 32                       Tiggo 4 Pro I  52 460     1.5     113  2024
# 35                                  H3   6 308     1.5     177  2024
# 57               Okavango I Рестайлинг  17 169     2.0     200  2023
# 60                Tiggo 8 I Рестайлинг  22 000     1.5     147  2022
# ...                                ...     ...     ...     ...   ...
# 3010  Monjaro (Xingyue L) I Рестайлинг      10     2.0     238  2025
# 3011                              Icon       1     1.5     181  2024
# 3012                              Icon      10     1.5     181  2024
# 3013                         Atlas Pro  58 000     1.5     177  2022
# 3014  Monjaro (Xingyue L) I Рестайлинг      10     2.0     238  2025
#
#           price Цена до, руб        color  ... is_new          city_group  \
# 4     2 320 000    2 320 000        серый  ...  False              Москва
# 32    1 490 000    1 490 000        серый  ...  False              Москва
# 35    2 650 000    2 650 000       чёрный  ...  False              Москва
# 57    2 980 000    2 980 000        синий  ...  False  Московская область
# 60    1 500 000    1 500 000        серый  ...  False              Москва
# ...         ...          ...          ...  ...    ...                 ...
# 3010  3 830 000    3 830 000  серебристый  ...  False              Москва
# 3011  2 699 999    2 699 999      голубой  ...  False              Москва
# 3012  2 699 999    2 699 999        серый  ...  False              Москва
# 3013  2 100 000    2 100 000        синий  ...  False  Московская область
# 3014  3 750 000    3 750 000      зелёный  ...  False              Москва
#
#      base_model generation is_restyling  is_pro is_max  car_class  is_premium  \
# 4            H3          1            0       0      0        SUV           0
# 32        Tiggo          1            0       1      0      Other           0
# 35           H3          1            0       0      0        SUV           0
# 57     Okavango          1            1       0      0      Other           0
# 60        Tiggo          1            1       0      0      Other           0
# ...         ...        ...          ...     ...    ...        ...         ...
# 3010    Monjaro          1            1       0      0  Crossover           1
# 3011       Icon          1            0       0      0      Other           0
# 3012       Icon          1            0       0      0      Other           0
# 3013      Atlas          1            0       1      0        SUV           0
# 3014    Monjaro          1            1       0      0  Crossover           1
#
#       model_popularity
# 4                    4
# 32                 270
# 35                   4
# 57                   7
# 60                 270
# ...                ...
# 3010               319
# 3011                80
# 3012                80
# 3013               132
# 3014               319
#
# [1315 rows x 25 columns]

# %%
data.year.value_counts()
# Out:
# year
# 2024    497
# 2025    251
# 2022    202
# 2023    195
# 2020     60
# 2021     52
# 2011     31
# 2018      7
# 2019      5
# 2009      3
# 2007      3
# 2014      3
# 2012      2
# 2010      1
# 2015      1
# 2013      1
# 2008      1
# Name: count, dtype: int64

# %%
current_year = 2025
data['age'] = current_year - data['year'].astype(float)
data
# Out:
#                                         name  brand  \
# 4                                   Haval H3  Haval
# 32                       Chery Tiggo 4 Pro I  Chery
# 35                                  Haval H3  Haval
# 57               Geely Okavango I Рестайлинг  Geely
# 60                Chery Tiggo 8 I Рестайлинг  Chery
# ...                                      ...    ...
# 3010  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
# 3011                              Geely Icon  Geely
# 3012                              Geely Icon  Geely
# 3013                         Geely Atlas Pro  Geely
# 3014  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
#
#                                  model mileage power_1 power_2  year  \
# 4                                   H3  12 000     1.5     177  2024
# 32                       Tiggo 4 Pro I  52 460     1.5     113  2024
# 35                                  H3   6 308     1.5     177  2024
# 57               Okavango I Рестайлинг  17 169     2.0     200  2023
# 60                Tiggo 8 I Рестайлинг  22 000     1.5     147  2022
# ...                                ...     ...     ...     ...   ...
# 3010  Monjaro (Xingyue L) I Рестайлинг      10     2.0     238  2025
# 3011                              Icon       1     1.5     181  2024
# 3012                              Icon      10     1.5     181  2024
# 3013                         Atlas Pro  58 000     1.5     177  2022
# 3014  Monjaro (Xingyue L) I Рестайлинг      10     2.0     238  2025
#
#           price Цена до, руб        color  ...          city_group base_model  \
# 4     2 320 000    2 320 000        серый  ...              Москва         H3
# 32    1 490 000    1 490 000        серый  ...              Москва      Tiggo
# 35    2 650 000    2 650 000       чёрный  ...              Москва         H3
# 57    2 980 000    2 980 000        синий  ...  Московская область   Okavango
# 60    1 500 000    1 500 000        серый  ...              Москва      Tiggo
# ...         ...          ...          ...  ...                 ...        ...
# 3010  3 830 000    3 830 000  серебристый  ...              Москва    Monjaro
# 3011  2 699 999    2 699 999      голубой  ...              Москва       Icon
# 3012  2 699 999    2 699 999        серый  ...              Москва       Icon
# 3013  2 100 000    2 100 000        синий  ...  Московская область      Atlas
# 3014  3 750 000    3 750 000      зелёный  ...              Москва    Monjaro
#
#      generation is_restyling is_pro  is_max  car_class is_premium  \
# 4             1            0      0       0        SUV          0
# 32            1            0      1       0      Other          0
# 35            1            0      0       0        SUV          0
# 57            1            1      0       0      Other          0
# 60            1            1      0       0      Other          0
# ...         ...          ...    ...     ...        ...        ...
# 3010          1            1      0       0  Crossover          1
# 3011          1            0      0       0      Other          0
# 3012          1            0      0       0      Other          0
# 3013          1            0      1       0        SUV          0
# 3014          1            1      0       0  Crossover          1
#
#       model_popularity  age
# 4                    4  1.0
# 32                 270  1.0
# 35                   4  1.0
# 57                   7  2.0
# 60                 270  3.0
# ...                ...  ...
# 3010               319  0.0
# 3011                80  1.0
# 3012                80  1.0
# 3013               132  3.0
# 3014               319  0.0
#
# [1315 rows x 26 columns]

# %%
target = 'price'
numeric_feats = ['mileage', 'power_1', 'power_2', 'model_popularity', 'age', 'generation']
cat_feats = ['brand', 'color', 'color_group', 'gearbox', 'drive', 'fuel_type', 'city', 'city_group', 'base_model', 'car_class']
dummies = ['is_new', 'is_restyling', 'is_pro', 'is_max', 'is_premium']

# %%
for col in numeric_feats:
    try:
        data[col] = data[col].str.replace('\xa0', '').astype(float)
    except:
        data[col] = data[col].astype(float)
data
# Out:
#                                         name  brand  \
# 4                                   Haval H3  Haval
# 32                       Chery Tiggo 4 Pro I  Chery
# 35                                  Haval H3  Haval
# 57               Geely Okavango I Рестайлинг  Geely
# 60                Chery Tiggo 8 I Рестайлинг  Chery
# ...                                      ...    ...
# 3010  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
# 3011                              Geely Icon  Geely
# 3012                              Geely Icon  Geely
# 3013                         Geely Atlas Pro  Geely
# 3014  Geely Monjaro (Xingyue L) I Рестайлинг  Geely
#
#                                  model  mileage  power_1  power_2  year  \
# 4                                   H3  12000.0      1.5    177.0  2024
# 32                       Tiggo 4 Pro I  52460.0      1.5    113.0  2024
# 35                                  H3   6308.0      1.5    177.0  2024
# 57               Okavango I Рестайлинг  17169.0      2.0    200.0  2023
# 60                Tiggo 8 I Рестайлинг  22000.0      1.5    147.0  2022
# ...                                ...      ...      ...      ...   ...
# 3010  Monjaro (Xingyue L) I Рестайлинг     10.0      2.0    238.0  2025
# 3011                              Icon      1.0      1.5    181.0  2024
# 3012                              Icon     10.0      1.5    181.0  2024
# 3013                         Atlas Pro  58000.0      1.5    177.0  2022
# 3014  Monjaro (Xingyue L) I Рестайлинг     10.0      2.0    238.0  2025
#
#           price Цена до, руб        color  ...          city_group base_model  \
# 4     2 320 000    2 320 000        серый  ...              Москва         H3
# 32    1 490 000    1 490 000        серый  ...              Москва      Tiggo
# 35    2 650 000    2 650 000       чёрный  ...              Москва         H3
# 57    2 980 000    2 980 000        синий  ...  Московская область   Okavango
# 60    1 500 000    1 500 000        серый  ...              Москва      Tiggo
# ...         ...          ...          ...  ...                 ...        ...
# 3010  3 830 000    3 830 000  серебристый  ...              Москва    Monjaro
# 3011  2 699 999    2 699 999      голубой  ...              Москва       Icon
# 3012  2 699 999    2 699 999        серый  ...              Москва       Icon
# 3013  2 100 000    2 100 000        синий  ...  Московская область      Atlas
# 3014  3 750 000    3 750 000      зелёный  ...              Москва    Monjaro
#
#      generation is_restyling is_pro  is_max  car_class is_premium  \
# 4           1.0            0      0       0        SUV          0
# 32          1.0            0      1       0      Other          0
# 35          1.0            0      0       0        SUV          0
# 57          1.0            1      0       0      Other          0
# 60          1.0            1      0       0      Other          0
# ...         ...          ...    ...     ...        ...        ...
# 3010        1.0            1      0       0  Crossover          1
# 3011        1.0            0      0       0      Other          0
# 3012        1.0            0      0       0      Other          0
# 3013        1.0            0      1       0        SUV          0
# 3014        1.0            1      0       0  Crossover          1
#
#       model_popularity  age
# 4                  4.0  1.0
# 32               270.0  1.0
# 35                 4.0  1.0
# 57                 7.0  2.0
# 60               270.0  3.0
# ...                ...  ...
# 3010             319.0  0.0
# 3011              80.0  1.0
# 3012              80.0  1.0
# 3013             132.0  3.0
# 3014             319.0  0.0
#
# [1315 rows x 26 columns]

# %%
data['price'] = data['price'].str.replace('\xa0', '').astype(float)

# %%
cols = cat_feats + numeric_feats + dummies + [target]

data = data[cols].reset_index(drop=True)

# %%
data
# Out:
#       brand        color  color_group   gearbox     drive fuel_type      city  \
# 0     Haval        серый  Нейтральные     робот    полный    Бензин    Москва
# 1     Chery        серый  Нейтральные  механика  передний    Бензин    Москва
# 2     Haval       чёрный  Нейтральные     робот    полный    Бензин    Москва
# 3     Geely        синий     Холодные     робот  передний    Бензин  Балашиха
# 4     Chery        серый  Нейтральные     робот  передний    Бензин    Москва
# ...     ...          ...          ...       ...       ...       ...       ...
# 1310  Geely  серебристый  Нейтральные   автомат    полный    Бензин    Москва
# 1311  Geely      голубой     Холодные     робот  передний    Бензин    Москва
# 1312  Geely        серый  Нейтральные     робот  передний    Бензин    Москва
# 1313  Geely        синий     Холодные     робот    полный    Бензин  Одинцово
# 1314  Geely      зелёный     Холодные   автомат    полный    Бензин    Москва
#
#               city_group base_model  car_class  ...  power_2  \
# 0                 Москва         H3        SUV  ...    177.0
# 1                 Москва      Tiggo      Other  ...    113.0
# 2                 Москва         H3        SUV  ...    177.0
# 3     Московская область   Okavango      Other  ...    200.0
# 4                 Москва      Tiggo      Other  ...    147.0
# ...                  ...        ...        ...  ...      ...
# 1310              Москва    Monjaro  Crossover  ...    238.0
# 1311              Москва       Icon      Other  ...    181.0
# 1312              Москва       Icon      Other  ...    181.0
# 1313  Московская область      Atlas        SUV  ...    177.0
# 1314              Москва    Monjaro  Crossover  ...    238.0
#
#       model_popularity  age  generation  is_new  is_restyling  is_pro  is_max  \
# 0                  4.0  1.0         1.0   False             0       0       0
# 1                270.0  1.0         1.0   False             0       1       0
# 2                  4.0  1.0         1.0   False             0       0       0
# 3                  7.0  2.0         1.0   False             1       0       0
# 4                270.0  3.0         1.0   False             1       0       0
# ...                ...  ...         ...     ...           ...     ...     ...
# 1310             319.0  0.0         1.0   False             1       0       0
# 1311              80.0  1.0         1.0   False             0       0       0
# 1312              80.0  1.0         1.0   False             0       0       0
# 1313             132.0  3.0         1.0   False             0       1       0
# 1314             319.0  0.0         1.0   False             1       0       0
#
#       is_premium      price
# 0              0  2320000.0
# 1              0  1490000.0
# 2              0  2650000.0
# 3              0  2980000.0
# 4              0  1500000.0
# ...          ...        ...
# 1310           1  3830000.0
# 1311           0  2699999.0
# 1312           0  2699999.0
# 1313           0  2100000.0
# 1314           1  3750000.0
#
# [1315 rows x 22 columns]

# %%
existing_columns = set(data.columns)
new_features = []

# Удельная мощность
if 'power_density' not in existing_columns:
        # Рассчитываем удельную мощность
        data['power_density'] = data["power_2"] / data["power_1"]
        new_features.append('power_density')
        print("Добавлен признак 'power_density'")

# Взаимодействие пробега и возраста
if 'mileage_age_interaction' not in existing_columns:
    mileage_col = 'Пробег, км' if 'Пробег, км' in existing_columns else 'mileage'

    if mileage_col in existing_columns and 'age' in data.columns:
        if data[mileage_col].dtype == 'object':
            mileage_numeric = data[mileage_col].copy()
            
            if 'is_new' in data.columns:
                if data['is_new'].dtype == bool:
                    mileage_numeric.loc[data['is_new'] == True] = '0'
                else:
                    mileage_numeric.loc[data['is_new'] == 1] = '0'
            
            mileage_numeric = mileage_numeric.replace({'Новый': '0'})
            
            mileage_numeric = pd.to_numeric(
                mileage_numeric.astype(str).str.replace(' ', ''), 
                errors='coerce'
            )
        else:
            mileage_numeric = data[mileage_col]
            
            if 'is_new' in data.columns:
                if data['is_new'].dtype == bool:
                    mileage_numeric.loc[data['is_new'] == True] = 0
                else:
                    mileage_numeric.loc[data['is_new'] == 1] = 0
        
        data['mileage_age_interaction'] = mileage_numeric * data['age']
        
        if 'is_new' in data.columns:
            if data['is_new'].dtype == bool:
                data.loc[data['is_new'] == True, 'mileage_age_interaction'] = 0
            else:
                data.loc[data['is_new'] == 1, 'mileage_age_interaction'] = 0
        
        new_features.append('mileage_age_interaction')
        print("Добавлен признак 'mileage_age_interaction'")
# Out:
# Добавлен признак 'power_density'
# Добавлен признак 'mileage_age_interaction'

# %%
data.to_csv('cars_clean')
